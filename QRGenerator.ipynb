# %%
# !pip install pyqrcode
# !pip install  pillow
# !pip install pypng
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import pyqrcode
from PIL import Image
link = input("Enter the text which you show on the during the scan:")
company = pyqrcode.create(link)
company.png("QRCode.png", scale= 5)
Image.open("QRCode.png")
# Out:
# Enter the text which you show on the during the scan:https://web.whatsapp.com/
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=205x205>
